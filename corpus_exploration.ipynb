# %%
import os
from dataset import SSTDataset
from utils import build_vocab
from vocab import Vocab
# %load_ext autoreload
# %autoreload 2

from spacy import displacy

train_dir = 'training-treebank'
vocab = Vocab(filename=vocab_file)
dataset = SSTDataset(train_dir, vocab, 3)
# Out:
# ...
# 100%|██████████| 965/965 [00:00<00:00, 89884.60it/s]
# 235it [00:00, 10993.57it/s]
# 965it [00:00, 17752.67it/s]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for tree in dataset.trees[:5]:
    displacy.render(tree.visualize(), style='dep', manual=True, jupyter=True, options={'compact': False})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2150" height="749.5" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">0</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Z</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">1</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">mogę</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">0</tspan>
# </text>
#
# ...

# %%
from IPython.core.display import display, HTML
html = displacy.render(dataset.trees[1].visualize(), style='dep', manual=True, jupyter=False, options={'compact': False})
display(HTML(html.replace('width="1275" height="574.5"', 'width="300px" height="300px"')))
# Tried to make them smaller but failed
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="300px" height="300px" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">root</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">0</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">0</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">jak</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">0</tspan>
# </text>
#
# ...
